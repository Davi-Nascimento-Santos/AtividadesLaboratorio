# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
vinhoVermelho = pd.read_csv('winequality-red.csv', sep=";")
vinhoBranco = pd.read_csv("winequality-white.csv", sep=";")
vinhoVermelho
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))

# plotar os dados do DataFrame como um mapa de calor no primeiro gráfico
"""im = ax1.imshow(df_corr, cmap='viridis')
ax1.set_xticks(range(len(df_corr.columns)))
ax1.set_yticks(range(len(df_corr.index)))
ax1.set_xticklabels(df_corr.columns)
ax1.set_yticklabels(df_corr.index)
for i in range(len(df_corr.index)):
    for j in range(len(df_corr.columns)):
        text = ax1.text(j, i, round(df_corr.iloc[i, j], 2),
                       ha='center', va='center', color='w')
ax1.set_title('Matriz de Correlação')
"""
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[10])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de alcohol com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[1])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de volatile acidity com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[4])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de chlorides com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[2])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de citric acid com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[9])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de sulphates com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar um mapa de calor
fig, ax = plt.subplots(figsize=(18, 5))
im = ax.imshow(df_corr, cmap='viridis')

# adicionar as labels dos eixos
ax.set_xticks(np.arange(len(df_corr.columns)))
ax.set_yticks(np.arange(len(df_corr.index)))
ax.set_xticklabels(df_corr.columns,  rotation=45, ha='right')
ax.set_yticklabels(df_corr.index)

# adicionar anotações de texto
for i in range(len(df_corr.index)):
    for j in range(len(df_corr.columns)):
        text = ax.text(j, i, round(df_corr.iloc[i, j], 2),
                       ha='center', va='center', color='w')

# adicionar a barra de cores
cbar = ax.figure.colorbar(im, ax=ax)

# adicionar o título
ax.set_title('Matriz de Correlação')

# mostrar o mapa de calor
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoBranco.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))

# plotar os dados do DataFrame como um mapa de calor no primeiro gráfico
"""im = ax1.imshow(df_corr, cmap='viridis')
ax1.set_xticks(range(len(df_corr.columns)))
ax1.set_yticks(range(len(df_corr.index)))
ax1.set_xticklabels(df_corr.columns)
ax1.set_yticklabels(df_corr.index)
for i in range(len(df_corr.index)):
    for j in range(len(df_corr.columns)):
        text = ax1.text(j, i, round(df_corr.iloc[i, j], 2),
                       ha='center', va='center', color='w')
ax1.set_title('Matriz de Correlação')
"""
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[10])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de alcohol com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoBranco.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[1])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de volatile acidity com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[4])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de chlorides com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoBranco.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[2])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de citric acid com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoVermelho.corr())

# criar os gráficos
fig, ax2 = plt.subplots(figsize=(18, 5))
# plotar os dados do DataFrame como um gráfico de barras no segundo gráfico
ax2.bar(df_corr.columns, df_corr.iloc[9])
ax2.set_xlabel('Atributos')
ax2.set_ylabel('Coeficiente de Correlação')
ax2.set_title('Coeficiente de Correlação de sulphates com os outros atributos')

# ajustar a posição dos subplots
plt.subplots_adjust(wspace=0.5)

# exibir os gráficos
plt.show()

# %%
# converter a matriz em um DataFrame
df_corr = pd.DataFrame(vinhoBranco.corr())

# criar um mapa de calor
fig, ax = plt.subplots(figsize=(18, 5))
im = ax.imshow(df_corr, cmap='viridis')

# adicionar as labels dos eixos
ax.set_xticks(np.arange(len(df_corr.columns)))
ax.set_yticks(np.arange(len(df_corr.index)))
ax.set_xticklabels(df_corr.columns,  rotation=45, ha='right')
ax.set_yticklabels(df_corr.index)

# adicionar anotações de texto
for i in range(len(df_corr.index)):
    for j in range(len(df_corr.columns)):
        text = ax.text(j, i, round(df_corr.iloc[i, j], 2),
                       ha='center', va='center', color='w')

# adicionar a barra de cores
cbar = ax.figure.colorbar(im, ax=ax)

# adicionar o título
ax.set_title('Matriz de Correlação')

# mostrar o mapa de calor
plt.show()

# %%
# Dataset de exemplo
data = vinhoBranco["quality"]

# Calcule a média e o desvio padrão dos dados
mean = np.mean(data)
std = np.std(data)

# Defina o limite superior e inferior usando a regra dos três desvios padrão
upper_limit = mean + 5 * std
lower_limit = mean - 5 * std

# Encontre os outliers
outliers = [x for x in data if x > upper_limit or x < lower_limit]

# Imprima os resultados
print("Média:", mean)
print("Maior: ", data.max())
print("Menor: ", data.min())
print("Desvio padrão:", std)
print("Limite superior:", upper_limit)
print("Limite inferior:", lower_limit)
print("Outliers:", len(outliers))
plt.plot(data)

# Adiciona um título ao gráfico
plt.title('Meu gráfico')

# Adiciona rótulos aos eixos x e y
plt.xlabel('Tempo')
plt.ylabel('Valor')

# Exibe o gráfico
plt.show()
# Out:
# Média: 5.87790935075541
# Maior:  9
# Menor:  3
# Desvio padrão: 0.8855481621683543
# Limite superior: 10.305650161597182
# Limite inferior: 1.4501685399136388
# Outliers: 0
